# %%
import importlib
from pathlib import Path
import sys
import warnings

import numpy as np
import pandas as pd

warnings.simplefilter('ignore')
project_root = Path.cwd().resolve().parents[1]
sys.path.append(str(project_root / 'src'))

from func_data_build import build_dataset
from func_gibbs.gibbs_notebook_utils import (
    display_hmc_posterior_prior,
    display_hmc_results,
    format_sample_window,
    prepare_gibbs_sample,
    save_idata_map,
)
from func_gibbs.gibbs_wrappers import draws_to_idata

seed = 0
n_iter = 12000
burn = 4000
thin = 5

import func_gibbs.gibbs_wrappers as gibbs_module
from func_gibbs.gibbs_wrappers import run_hsa_steady

prior_specs = {
    'alpha': (0.5, 0.2),
    'kappa_0': (0.1, 0.2),
    'delta': (0.1, 0.2),
    'phi_1': (0.7, 0.2),
    'rho_1': (0.2, 0.2),
    'rho_2': (0.2, 0.2),
}

data_dir = project_root / "data"
idat_dir = project_root / "results" / "idata"
tex_root_dir = project_root / "results" / "tex" / "table"
base_fig_dir = project_root / "results" / "fig"
tex_dir = tex_root_dir / 'gibbs_hsa_steady'

data_origin = build_dataset(data_dir)

inflation_specs = {
    'ppi': {
        'pi': 'pi_ppi',
        'pi_prev': 'pi_ppi_prev',
        'pi_expect': 'Epi_spf_gdp',
    },
    'cpi': {
        'pi': 'pi_cpi',
        'pi_prev': 'pi_cpi_prev',
        'pi_expect': 'Epi_spf_cpi',
    },
}

x_specs = {
    'unemp_gap': 'unemp_gap',
    'output_gap_BN': 'output_gap_BN',
    'markup_BN_inv': 'markup_BN_inv',
    'markup_inv': 'markup_inv',
}

# %%
period_label = '1982_2012'
period_title = '1982-2012'
n_name = 'gustavo'
n_col = 'N_Gustavo'
data = data_origin.loc['1982-01-01':'2012-12-31'].copy()
data['DATE'] = pd.to_datetime(data.index)


def make_idata_filename(model_name: str, period_label: str) -> str:
    parts = model_name.lower().split('_')
    infl = parts[0]
    family = parts[1]
    if parts[2] == 'orth':
        corr = 'uncorr'
        gap = '_'.join(parts[3:])
    else:
        corr = 'corr'
        gap = '_'.join(parts[2:])
    return f"{infl}_{family}_{gap}_{period_label}_{corr}"


gibbs_module = importlib.reload(gibbs_module)
run_hsa_steady = gibbs_module.run_hsa_steady
draws_to_idata = gibbs_module.draws_to_idata

dict_idata = {}
dict_draws = {}
print(f'=== Run Gibbs HSA steady models ({n_name}, {period_title}) ===')

for infl, spec in inflation_specs.items():
    print(f'--- Inflation: {infl} ---')

    for x_name, x_col in x_specs.items():
        sample = prepare_gibbs_sample(
            data,
            pi_col=spec['pi'],
            pi_prev_col=spec['pi_prev'],
            pi_expect_col=spec['pi_expect'],
            x_col=x_col,
            x_prev_col=f'{x_col}_prev',
            n_col=n_col,
        )
        print(f'    Sample {x_name}: {format_sample_window(sample)}')

        run_name = f"{infl.upper()}_HSA_{x_name}"
        orth_run_name = f"{infl.upper()}_HSA_orth_{x_name}"
        print(f'    Running Gibbs model: {run_name}')
        draws = run_hsa_steady(
            pi=np.asarray(sample['pi'], dtype=float),
            pi_prev=np.asarray(sample['pi_prev'], dtype=float),
            pi_expect=np.asarray(sample['pi_expect'], dtype=float),
            x=np.asarray(sample['x'], dtype=float),
            x_prev=np.asarray(sample['x_prev'], dtype=float),
            N=np.asarray(sample['N'], dtype=float),
            prior_specs=prior_specs,
            n_iter=n_iter,
            burn=burn,
            thin=thin,
            rng=np.random.default_rng(seed),
            orth=False,
        )
        dict_draws[run_name] = draws
        dict_idata[run_name] = draws_to_idata(draws)

        print(f'    Running Gibbs model: {orth_run_name}')
        orth_draws = run_hsa_steady(
            pi=np.asarray(sample['pi'], dtype=float),
            pi_prev=np.asarray(sample['pi_prev'], dtype=float),
            pi_expect=np.asarray(sample['pi_expect'], dtype=float),
            x=np.asarray(sample['x'], dtype=float),
            x_prev=np.asarray(sample['x_prev'], dtype=float),
            N=np.asarray(sample['N'], dtype=float),
            prior_specs=prior_specs,
            n_iter=n_iter,
            burn=burn,
            thin=thin,
            rng=np.random.default_rng(seed),
            orth=True,
        )
        dict_draws[orth_run_name] = orth_draws
        dict_idata[orth_run_name] = draws_to_idata(orth_draws)

print('=== All Gibbs HSA steady models finished ===')

base_models_to_show = [
    'HSA_unemp_gap',
    'HSA_output_gap_BN',
    'HSA_markup_BN_inv',
    'HSA_markup_inv',
]

for infl in inflation_specs.keys():
    models_to_show = [f"{infl.upper()}_{m}" for m in base_models_to_show]
    orth_models_to_show = [m.replace('_HSA_', '_HSA_orth_') for m in models_to_show]
    all_models_to_show = orth_models_to_show + models_to_show
    dict_items_fill = {k: dict_idata[k] for k in all_models_to_show if k in dict_idata}

    display_hmc_results(
        dict_items_fill,
        prior_specs,
        models_to_show=all_models_to_show,
        tex_dir=tex_dir / period_label / infl.lower(),
        params=('alpha', 'kappa_0', 'delta', 'phi_1', 'rho_1', 'rho_2'),
        title=f'Gibbs HSA Steady Results ({infl.upper()})',
    )

    fig_dir = base_fig_dir / 'gibbs_hsa_steady' / period_label / infl.lower()
    fig_dir.mkdir(parents=True, exist_ok=True)

    display_hmc_posterior_prior(
        dict_items_fill,
        prior_specs,
        models_to_show=all_models_to_show,
        fig_dir=fig_dir,
        params=('alpha', 'kappa_0', 'delta', 'phi_1', 'rho_1', 'rho_2'),
        title=f'Prior vs Posterior ({infl.upper()})',
    )

    idata_dir = idat_dir / f'gibbs_hsa_steady_{period_label}_{infl.lower()}'
    dict_items_save = {make_idata_filename(k, period_label): v for k, v in dict_items_fill.items()}
    save_idata_map(dict_items_save, idata_dir)
# Out:
# === Run Gibbs HSA steady models (gustavo, 1982-2012) ===
# --- Inflation: ppi ---
#     Sample unemp_gap: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: PPI_HSA_unemp_gap
#     Running Gibbs model: PPI_HSA_orth_unemp_gap
#     Sample output_gap_BN: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: PPI_HSA_output_gap_BN
#     Running Gibbs model: PPI_HSA_orth_output_gap_BN
#     Sample markup_BN_inv: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: PPI_HSA_markup_BN_inv
#     Running Gibbs model: PPI_HSA_orth_markup_BN_inv
#     Sample markup_inv: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: PPI_HSA_markup_inv
#     Running Gibbs model: PPI_HSA_orth_markup_inv
# --- Inflation: cpi ---
#     Sample unemp_gap: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: CPI_HSA_unemp_gap
#     Running Gibbs model: CPI_HSA_orth_unemp_gap
#     Sample output_gap_BN: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: CPI_HSA_output_gap_BN
#     Running Gibbs model: CPI_HSA_orth_output_gap_BN
#     Sample markup_BN_inv: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: CPI_HSA_markup_BN_inv
#     Running Gibbs model: CPI_HSA_orth_markup_BN_inv
#     Sample markup_inv: 1982Q1-2012Q4 (T=124)
#     Running Gibbs model: CPI_HSA_markup_inv
#     Running Gibbs model: CPI_HSA_orth_markup_inv
# === All Gibbs HSA steady models finished ===
# Gibbs HSA Steady Results (PPI)
#                          model    param      mean    ci_2.5   ci_97.5
# 0       PPI_HSA_orth_unemp_gap    alpha  0.776066  0.682791  0.877323
# 1       PPI_HSA_orth_unemp_gap  kappa_0 -0.004004 -0.309742  0.308289
# 2       PPI_HSA_orth_unemp_gap    delta  0.023042 -0.050040  0.083792
# 3       PPI_HSA_orth_unemp_gap    phi_1  0.947662  0.896646  0.989237
# 4       PPI_HSA_orth_unemp_gap    rho_1  0.599619  0.394519  0.777467
# 5       PPI_HSA_orth_unemp_gap    rho_2  0.175368 -0.032742  0.389491
# 6   PPI_HSA_orth_output_gap_BN    alpha  0.794116  0.696258  0.884405
# 7   PPI_HSA_orth_output_gap_BN  kappa_0  0.179219 -0.163418  0.507075
# 8   PPI_HSA_orth_output_gap_BN    delta  0.013825 -0.036613  0.069770
# 9   PPI_HSA_orth_output_gap_BN    phi_1  0.912794  0.851982  0.962395
# 10  PPI_HSA_orth_output_gap_BN    rho_1  0.599619  0.394519  0.777467
# 11  PPI_HSA_orth_output_gap_BN    rho_2  0.175368 -0.032742  0.389491
# 12  PPI_HSA_orth_markup_BN_inv    alpha  0.792319  0.691296  0.884150
# 13  PPI_HSA_orth_markup_BN_inv  kappa_0  0.060398 -0.270672  0.394555
# 14  PPI_HSA_orth_markup_BN_inv    delta -0.037615 -0.129443  0.054294
# 15  PPI_HSA_orth_markup_BN_inv    phi_1  0.662182  0.539593  0.760969
# 16  PPI_HSA_orth_markup_BN_inv    rho_1  0.599619  0.394519  0.777467
# 17  PPI_HSA_orth_markup_BN_inv    rho_2  0.175368 -0.032742  0.389491
# 18     PPI_HSA_orth_markup_inv    alpha  0.787343  0.664283  0.882255
# 19     PPI_HSA_orth_markup_inv  kappa_0  0.096368 -0.234108  0.421624
# 20     PPI_HSA_orth_markup_inv    delta -0.035344 -0.123170  0.054247
# 21     PPI_HSA_orth_markup_inv    phi_1  0.999178  0.997280  1.000703
# 22     PPI_HSA_orth_markup_inv    rho_1  0.599619  0.394519  0.777467
# 23     PPI_HSA_orth_markup_inv    rho_2  0.175368 -0.032742  0.389491
# 24           PPI_HSA_unemp_gap    alpha  0.781327  0.676551  0.870891
# 25           PPI_HSA_unemp_gap  kappa_0  0.023032 -0.335286  0.372179
# 26           PPI_HSA_unemp_gap    delta  0.009527 -0.051077  0.065986
# 27           PPI_HSA_unemp_gap    phi_1  0.951197  0.898066  1.000313
# 28           PPI_HSA_unemp_gap    rho_1  0.626365  0.408635  0.860678
# 29           PPI_HSA_unemp_gap    rho_2  0.198501 -0.015491  0.414111
# 30       PPI_HSA_output_gap_BN    alpha  0.811081  0.724649  0.905163
# 31       PPI_HSA_output_gap_BN  kappa_0  0.159871 -0.215166  0.496717
# 32       PPI_HSA_output_gap_BN    delta  0.009275 -0.054922  0.073067
# 33       PPI_HSA_output_gap_BN    phi_1  0.916425  0.852526  0.974387
# 34       PPI_HSA_output_gap_BN    rho_1  0.626365  0.408635  0.860678
# 35       PPI_HSA_output_gap_BN    rho_2  0.198501 -0.015491  0.414111
# 36       PPI_HSA_markup_BN_inv    alpha  0.795475  0.700237  0.892967
# 37       PPI_HSA_markup_BN_inv  kappa_0  0.079458 -0.301620  0.417820
# 38       PPI_HSA_markup_BN_inv    delta -0.049509 -0.172263  0.051829
# 39       PPI_HSA_markup_BN_inv    phi_1  0.668545  0.544707  0.788130
# 40       PPI_HSA_markup_BN_inv    rho_1  0.626365  0.408635  0.860678
# 41       PPI_HSA_markup_BN_inv    rho_2  0.198501 -0.015491  0.414111
# 42          PPI_HSA_markup_inv    alpha  0.786976  0.697831  0.891997
# 43          PPI_HSA_markup_inv  kappa_0  0.110252 -0.248155  0.490869
# 44          PPI_HSA_markup_inv    delta -0.038880 -0.141602  0.067707
# 45          PPI_HSA_markup_inv    phi_1  0.999288  0.997304  1.001120
# 46          PPI_HSA_markup_inv    rho_1  0.626365  0.408635  0.860678
# 47          PPI_HSA_markup_inv    rho_2  0.198501 -0.015491  0.414111
# Gibbs HSA Steady Results (CPI)
#                          model    param      mean    ci_2.5   ci_97.5
# 0       CPI_HSA_orth_unemp_gap    alpha  0.633686  0.527171  0.740777
# 1       CPI_HSA_orth_unemp_gap  kappa_0 -0.136012 -0.339418  0.074954
# 2       CPI_HSA_orth_unemp_gap    delta  0.033195  0.000292  0.063015
# 3       CPI_HSA_orth_unemp_gap    phi_1  0.947662  0.896646  0.989237
# 4       CPI_HSA_orth_unemp_gap    rho_1  0.599619  0.394519  0.777467
# 5       CPI_HSA_orth_unemp_gap    rho_2  0.175368 -0.032742  0.389491
# 6   CPI_HSA_orth_output_gap_BN    alpha  0.670710  0.554392  0.772928
# 7   CPI_HSA_orth_output_gap_BN  kappa_0  0.329150  0.026663  0.603489
# 8   CPI_HSA_orth_output_gap_BN    delta -0.033148 -0.073908  0.006775
# 9   CPI_HSA_orth_output_gap_BN    phi_1  0.912794  0.851982  0.962395
# 10  CPI_HSA_orth_output_gap_BN    rho_1  0.599619  0.394519  0.777467
# 11  CPI_HSA_orth_output_gap_BN    rho_2  0.175368 -0.032742  0.389491
# 12  CPI_HSA_orth_markup_BN_inv    alpha  0.650370  0.542982  0.754625
# 13  CPI_HSA_orth_markup_BN_inv  kappa_0  0.099411 -0.222559  0.416954
# 14  CPI_HSA_orth_markup_BN_inv    delta -0.013642 -0.054122  0.031334
# 15  CPI_HSA_orth_markup_BN_inv    phi_1  0.662182  0.539593  0.760969
# 16  CPI_HSA_orth_markup_BN_inv    rho_1  0.599619  0.394519  0.777467
# 17  CPI_HSA_orth_markup_BN_inv    rho_2  0.175368 -0.032742  0.389491
# 18     CPI_HSA_orth_markup_inv    alpha  0.646021  0.540869  0.746365
# 19     CPI_HSA_orth_markup_inv  kappa_0  0.121592 -0.204247  0.431442
# 20     CPI_HSA_orth_markup_inv    delta -0.030568 -0.068946  0.013787
# 21     CPI_HSA_orth_markup_inv    phi_1  0.999178  0.997280  1.000703
# 22     CPI_HSA_orth_markup_inv    rho_1  0.599619  0.394519  0.777467
# 23     CPI_HSA_orth_markup_inv    rho_2  0.175368 -0.032742  0.389491
# 24           CPI_HSA_unemp_gap    alpha  0.635851  0.520913  0.744744
# 25           CPI_HSA_unemp_gap  kappa_0 -0.105429 -0.398154  0.177499
# 26           CPI_HSA_unemp_gap    delta  0.026839 -0.009615  0.067644
# 27           CPI_HSA_unemp_gap    phi_1  0.950080  0.897305  0.998622
# 28           CPI_HSA_unemp_gap    rho_1  0.626365  0.408635  0.860678
# 29           CPI_HSA_unemp_gap    rho_2  0.198501 -0.015491  0.414111
# 30       CPI_HSA_output_gap_BN    alpha  0.687214  0.566716  0.807125
# 31       CPI_HSA_output_gap_BN  kappa_0  0.291820 -0.082430  0.596840
# 32       CPI_HSA_output_gap_BN    delta -0.027369 -0.066710  0.026352
# 33       CPI_HSA_output_gap_BN    phi_1  0.915279  0.853002  0.973601
# 34       CPI_HSA_output_gap_BN    rho_1  0.626365  0.408635  0.860678
# 35       CPI_HSA_output_gap_BN    rho_2  0.198501 -0.015491  0.414111
# 36       CPI_HSA_markup_BN_inv    alpha  0.653991  0.542505  0.765755
# 37       CPI_HSA_markup_BN_inv  kappa_0  0.090938 -0.276105  0.459009
# 38       CPI_HSA_markup_BN_inv    delta -0.013634 -0.072081  0.043876
# 39       CPI_HSA_markup_BN_inv    phi_1  0.664793  0.541316  0.787293
# 40       CPI_HSA_markup_BN_inv    rho_1  0.626365  0.408635  0.860678
# 41       CPI_HSA_markup_BN_inv    rho_2  0.198501 -0.015491  0.414111
# 42          CPI_HSA_markup_inv    alpha  0.644017  0.534358  0.757459
# 43          CPI_HSA_markup_inv  kappa_0  0.145317 -0.207658  0.520761
# 44          CPI_HSA_markup_inv    delta -0.034434 -0.085910  0.017707
# 45          CPI_HSA_markup_inv    phi_1  0.999289  0.997304  1.001117
# 46          CPI_HSA_markup_inv    rho_1  0.626365  0.408635  0.860678
# 47          CPI_HSA_markup_inv    rho_2  0.198501 -0.015491  0.414111

# %%
period_label = '1988_2017'
period_title = '1988-2017'
n_name = 'tnic'
n_col = 'N_TNIC'
data = data_origin.loc['1988-03-31':'2017-12-31'].copy()
data['DATE'] = pd.to_datetime(data.index)

gibbs_module = importlib.reload(gibbs_module)
run_hsa_steady = gibbs_module.run_hsa_steady
draws_to_idata = gibbs_module.draws_to_idata

dict_idata = {}
dict_draws = {}
print(f'=== Run Gibbs HSA steady models ({n_name}, {period_title}) ===')

for infl, spec in inflation_specs.items():
    print(f'--- Inflation: {infl} ---')

    for x_name, x_col in x_specs.items():
        sample = prepare_gibbs_sample(
            data,
            pi_col=spec['pi'],
            pi_prev_col=spec['pi_prev'],
            pi_expect_col=spec['pi_expect'],
            x_col=x_col,
            x_prev_col=f'{x_col}_prev',
            n_col=n_col,
        )
        print(f'    Sample {x_name}: {format_sample_window(sample)}')

        run_name = f"{infl.upper()}_HSA_{x_name}"
        orth_run_name = f"{infl.upper()}_HSA_orth_{x_name}"
        print(f'    Running Gibbs model: {run_name}')
        draws = run_hsa_steady(
            pi=np.asarray(sample['pi'], dtype=float),
            pi_prev=np.asarray(sample['pi_prev'], dtype=float),
            pi_expect=np.asarray(sample['pi_expect'], dtype=float),
            x=np.asarray(sample['x'], dtype=float),
            x_prev=np.asarray(sample['x_prev'], dtype=float),
            N=np.asarray(sample['N'], dtype=float),
            prior_specs=prior_specs,
            n_iter=n_iter,
            burn=burn,
            thin=thin,
            rng=np.random.default_rng(seed),
            orth=False,
        )
        dict_draws[run_name] = draws
        dict_idata[run_name] = draws_to_idata(draws)

        print(f'    Running Gibbs model: {orth_run_name}')
        orth_draws = run_hsa_steady(
            pi=np.asarray(sample['pi'], dtype=float),
            pi_prev=np.asarray(sample['pi_prev'], dtype=float),
            pi_expect=np.asarray(sample['pi_expect'], dtype=float),
            x=np.asarray(sample['x'], dtype=float),
            x_prev=np.asarray(sample['x_prev'], dtype=float),
            N=np.asarray(sample['N'], dtype=float),
            prior_specs=prior_specs,
            n_iter=n_iter,
            burn=burn,
            thin=thin,
            rng=np.random.default_rng(seed),
            orth=True,
        )
        dict_draws[orth_run_name] = orth_draws
        dict_idata[orth_run_name] = draws_to_idata(orth_draws)

print('=== All Gibbs HSA steady models finished ===')

base_models_to_show = [
    'HSA_unemp_gap',
    'HSA_output_gap_BN',
    'HSA_markup_BN_inv',
    'HSA_markup_inv',
]

for infl in inflation_specs.keys():
    models_to_show = [f"{infl.upper()}_{m}" for m in base_models_to_show]
    orth_models_to_show = [m.replace('_HSA_', '_HSA_orth_') for m in models_to_show]
    all_models_to_show = orth_models_to_show + models_to_show
    dict_items_fill = {k: dict_idata[k] for k in all_models_to_show if k in dict_idata}

    display_hmc_results(
        dict_items_fill,
        prior_specs,
        models_to_show=all_models_to_show,
        tex_dir=tex_dir / period_label / infl.lower(),
        params=('alpha', 'kappa_0', 'delta', 'phi_1', 'rho_1', 'rho_2'),
        title=f'Gibbs HSA Steady Results ({infl.upper()})',
    )

    fig_dir = base_fig_dir / 'gibbs_hsa_steady' / period_label / infl.lower()
    fig_dir.mkdir(parents=True, exist_ok=True)

    display_hmc_posterior_prior(
        dict_items_fill,
        prior_specs,
        models_to_show=all_models_to_show,
        fig_dir=fig_dir,
        params=('alpha', 'kappa_0', 'delta', 'phi_1', 'rho_1', 'rho_2'),
        title=f'Prior vs Posterior ({infl.upper()})',
    )

    idata_dir = idat_dir / f'gibbs_hsa_steady_{period_label}_{infl.lower()}'
    dict_items_save = {make_idata_filename(k, period_label): v for k, v in dict_items_fill.items()}
    save_idata_map(dict_items_save, idata_dir)
# Out:
# === Run Gibbs HSA steady models (tnic, 1988-2017) ===
# --- Inflation: ppi ---
#     Sample unemp_gap: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: PPI_HSA_unemp_gap
#     Running Gibbs model: PPI_HSA_orth_unemp_gap
#     Sample output_gap_BN: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: PPI_HSA_output_gap_BN
#     Running Gibbs model: PPI_HSA_orth_output_gap_BN
#     Sample markup_BN_inv: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: PPI_HSA_markup_BN_inv
#     Running Gibbs model: PPI_HSA_orth_markup_BN_inv
#     Sample markup_inv: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: PPI_HSA_markup_inv
#     Running Gibbs model: PPI_HSA_orth_markup_inv
# --- Inflation: cpi ---
#     Sample unemp_gap: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: CPI_HSA_unemp_gap
#     Running Gibbs model: CPI_HSA_orth_unemp_gap
#     Sample output_gap_BN: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: CPI_HSA_output_gap_BN
#     Running Gibbs model: CPI_HSA_orth_output_gap_BN
#     Sample markup_BN_inv: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: CPI_HSA_markup_BN_inv
#     Running Gibbs model: CPI_HSA_orth_markup_BN_inv
#     Sample markup_inv: 1988Q1-2017Q4 (T=120)
#     Running Gibbs model: CPI_HSA_markup_inv
#     Running Gibbs model: CPI_HSA_orth_markup_inv
# === All Gibbs HSA steady models finished ===
# Gibbs HSA Steady Results (PPI)
#                          model    param      mean    ci_2.5   ci_97.5
# 0       PPI_HSA_orth_unemp_gap    alpha  0.779418  0.680847  0.875175
# 1       PPI_HSA_orth_unemp_gap  kappa_0  0.018036 -0.375288  0.422157
# 2       PPI_HSA_orth_unemp_gap    delta  0.012326 -0.095620  0.155166
# 3       PPI_HSA_orth_unemp_gap    phi_1  0.946879  0.895273  1.005334
# 4       PPI_HSA_orth_unemp_gap    rho_1  0.592933  0.376760  0.811473
# 5       PPI_HSA_orth_unemp_gap    rho_2  0.193539  0.005008  0.398707
# 6   PPI_HSA_orth_output_gap_BN    alpha  0.778251  0.686246  0.880465
# 7   PPI_HSA_orth_output_gap_BN  kappa_0  0.105857 -0.261370  0.525299
# 8   PPI_HSA_orth_output_gap_BN    delta  0.079133 -0.062480  0.226233
# 9   PPI_HSA_orth_output_gap_BN    phi_1  0.918857  0.854970  0.991222
# 10  PPI_HSA_orth_output_gap_BN    rho_1  0.592933  0.376760  0.811473
# 11  PPI_HSA_orth_output_gap_BN    rho_2  0.193539  0.005008  0.398707
# 12  PPI_HSA_orth_markup_BN_inv    alpha  0.781000  0.673050  0.866615
# 13  PPI_HSA_orth_markup_BN_inv  kappa_0  0.048915 -0.333029  0.418466
# 14  PPI_HSA_orth_markup_BN_inv    delta -0.074077 -0.271100  0.120565
# 15  PPI_HSA_orth_markup_BN_inv    phi_1  0.591977  0.465032  0.736403
# 16  PPI_HSA_orth_markup_BN_inv    rho_1  0.592933  0.376760  0.811473
# 17  PPI_HSA_orth_markup_BN_inv    rho_2  0.193539  0.005008  0.398707
# 18     PPI_HSA_orth_markup_inv    alpha  0.781892  0.673859  0.864585
# 19     PPI_HSA_orth_markup_inv  kappa_0  0.075013 -0.304222  0.452925
# 20     PPI_HSA_orth_markup_inv    delta -0.008427 -0.205340  0.173732
# 21     PPI_HSA_orth_markup_inv    phi_1  0.999225  0.997204  1.001515
# 22     PPI_HSA_orth_markup_inv    rho_1  0.592933  0.376760  0.811473
# 23     PPI_HSA_orth_markup_inv    rho_2  0.193539  0.005008  0.398707
# 24           PPI_HSA_unemp_gap    alpha  0.787709  0.696233  0.877067
# 25           PPI_HSA_unemp_gap  kappa_0  0.078571 -0.340753  0.433470
# 26           PPI_HSA_unemp_gap    delta -0.021336 -0.136643  0.111010
# 27           PPI_HSA_unemp_gap    phi_1  0.944974  0.893629  1.000470
# 28           PPI_HSA_unemp_gap    rho_1  0.555417  0.319979  0.749405
# 29           PPI_HSA_unemp_gap    rho_2  0.226483 -0.009607  0.454545
# 30       PPI_HSA_output_gap_BN    alpha  0.801438  0.710287  0.892812
# 31       PPI_HSA_output_gap_BN  kappa_0  0.133002 -0.259326  0.476671
# 32       PPI_HSA_output_gap_BN    delta  0.042736 -0.100311  0.184582
# 33       PPI_HSA_output_gap_BN    phi_1  0.916107  0.852316  0.985357
# 34       PPI_HSA_output_gap_BN    rho_1  0.555417  0.319979  0.749405
# 35       PPI_HSA_output_gap_BN    rho_2  0.226483 -0.009607  0.454545
# 36       PPI_HSA_markup_BN_inv    alpha  0.785987  0.690901  0.882133
# 37       PPI_HSA_markup_BN_inv  kappa_0  0.039497 -0.364445  0.398058
# 38       PPI_HSA_markup_BN_inv    delta -0.067846 -0.265883  0.135133
# 39       PPI_HSA_markup_BN_inv    phi_1  0.585398  0.469477  0.723139
# 40       PPI_HSA_markup_BN_inv    rho_1  0.555417  0.319979  0.749405
# 41       PPI_HSA_markup_BN_inv    rho_2  0.226483 -0.009607  0.454545
# 42          PPI_HSA_markup_inv    alpha  0.787693  0.692203  0.886373
# 43          PPI_HSA_markup_inv  kappa_0  0.060698 -0.296389  0.444193
# 44          PPI_HSA_markup_inv    delta  0.011986 -0.170754  0.196381
# 45          PPI_HSA_markup_inv    phi_1  0.999142  0.997285  1.001326
# 46          PPI_HSA_markup_inv    rho_1  0.555417  0.319979  0.749405
# 47          PPI_HSA_markup_inv    rho_2  0.226483 -0.009607  0.454545
# Gibbs HSA Steady Results (CPI)
#                          model    param      mean    ci_2.5   ci_97.5
# 0       CPI_HSA_orth_unemp_gap    alpha  0.672820  0.561477  0.784008
# 1       CPI_HSA_orth_unemp_gap  kappa_0 -0.057804 -0.481203  0.383817
# 2       CPI_HSA_orth_unemp_gap    delta  0.029527 -0.092070  0.144076
# 3       CPI_HSA_orth_unemp_gap    phi_1  0.946879  0.895273  1.005334
# 4       CPI_HSA_orth_unemp_gap    rho_1  0.592933  0.376760  0.811473
# 5       CPI_HSA_orth_unemp_gap    rho_2  0.193539  0.005008  0.398707
# 6   CPI_HSA_orth_output_gap_BN    alpha  0.706656  0.590837  0.820779
# 7   CPI_HSA_orth_output_gap_BN  kappa_0  0.164504 -0.300636  0.531527
# 8   CPI_HSA_orth_output_gap_BN    delta -0.022316 -0.129110  0.105179
# 9   CPI_HSA_orth_output_gap_BN    phi_1  0.918857  0.854970  0.991222
# 10  CPI_HSA_orth_output_gap_BN    rho_1  0.592933  0.376760  0.811473
# 11  CPI_HSA_orth_output_gap_BN    rho_2  0.193539  0.005008  0.398707
# 12  CPI_HSA_orth_markup_BN_inv    alpha  0.688385  0.573066  0.793045
# 13  CPI_HSA_orth_markup_BN_inv  kappa_0  0.086357 -0.268140  0.467431
# 14  CPI_HSA_orth_markup_BN_inv    delta -0.029293 -0.130790  0.077439
# 15  CPI_HSA_orth_markup_BN_inv    phi_1  0.591977  0.465032  0.736403
# 16  CPI_HSA_orth_markup_BN_inv    rho_1  0.592933  0.376760  0.811473
# 17  CPI_HSA_orth_markup_BN_inv    rho_2  0.193539  0.005008  0.398707
# 18     CPI_HSA_orth_markup_inv    alpha  0.680766  0.566645  0.791740
# 19     CPI_HSA_orth_markup_inv  kappa_0  0.124079 -0.248566  0.506066
# 20     CPI_HSA_orth_markup_inv    delta -0.045475 -0.159552  0.063810
# 21     CPI_HSA_orth_markup_inv    phi_1  0.999225  0.997204  1.001515
# 22     CPI_HSA_orth_markup_inv    rho_1  0.592933  0.376760  0.811473
# 23     CPI_HSA_orth_markup_inv    rho_2  0.193539  0.005008  0.398707
# 24           CPI_HSA_unemp_gap    alpha  0.678033  0.572338  0.791405
# 25           CPI_HSA_unemp_gap  kappa_0  0.096333 -0.273688  0.480259
# 26           CPI_HSA_unemp_gap    delta -0.016442 -0.110487  0.079175
# 27           CPI_HSA_unemp_gap    phi_1  0.944077  0.892542  0.998012
# 28           CPI_HSA_unemp_gap    rho_1  0.555417  0.319979  0.749405
# 29           CPI_HSA_unemp_gap    rho_2  0.226483 -0.009607  0.454545
# 30       CPI_HSA_output_gap_BN    alpha  0.706368  0.597202  0.825423
# 31       CPI_HSA_output_gap_BN  kappa_0  0.110442 -0.231580  0.417604
# 32       CPI_HSA_output_gap_BN    delta -0.010349 -0.100911  0.082381
# 33       CPI_HSA_output_gap_BN    phi_1  0.914909  0.852232  0.981472
# 34       CPI_HSA_output_gap_BN    rho_1  0.555417  0.319979  0.749405
# 35       CPI_HSA_output_gap_BN    rho_2  0.226483 -0.009607  0.454545
# 36       CPI_HSA_markup_BN_inv    alpha  0.685033  0.569412  0.787935
# 37       CPI_HSA_markup_BN_inv  kappa_0  0.077427 -0.269985  0.426726
# 38       CPI_HSA_markup_BN_inv    delta -0.034926 -0.140621  0.087478
# 39       CPI_HSA_markup_BN_inv    phi_1  0.580099  0.462922  0.718993
# 40       CPI_HSA_markup_BN_inv    rho_1  0.555417  0.319979  0.749405
# 41       CPI_HSA_markup_BN_inv    rho_2  0.226483 -0.009607  0.454545
# 42          CPI_HSA_markup_inv    alpha  0.691552  0.568885  0.788193
# 43          CPI_HSA_markup_inv  kappa_0  0.066848 -0.293655  0.432517
# 44          CPI_HSA_markup_inv    delta -0.031509 -0.145531  0.084836
# 45          CPI_HSA_markup_inv    phi_1  0.999143  0.997282  1.001327
# 46          CPI_HSA_markup_inv    rho_1  0.555417  0.319979  0.749405
# 47          CPI_HSA_markup_inv    rho_2  0.226483 -0.009607  0.454545
